# %% [markdown]
# Importing of Libaries,Creating a Dataframe,Loading Data to the Dataframe & Running Test on the Dataframe

# %%
"""Link to download the dataset"""
# https://www.kaggle.com/datasets/aiaiaidavid/the-big-dataset-of-ultra-marathon-running/discussion/420633
# Out:
# 'Link to download the dataset'

# %%
"""installing python package libaries"""
# Pip install pandas
# Pip install seaborn
# Out:
# 'installing python package libaries'

# %%
# Importing of libaries
import pandas as pd
import seaborn as sb

# %%
# Creating a DataFrame named df and loading our csv file which contains the dataset(TWO_CENTURIES_OF_UM_RACES.csv) 
df = pd.read_csv('TWO_CENTURIES_OF_UM_RACES.csv')
# Out:
# C:\Users\Henry Nkeki Bill\AppData\Local\Temp\ipykernel_23016\692892121.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('TWO_CENTURIES_OF_UM_RACES.csv')

# %%
# Looking at the columns and rows in our dataframe (7,461,195 Rows) X (13 Columns)
df.shape
# Out:
# (7461195, 13)

# %%
# Looking at the column names in the dataframe
df.columns
# Out:
# Index(['Year of event', 'Event dates', 'Event name', 'Event distance/length',
#        'Event number of finishers', 'Athlete performance', 'Athlete club',
#        'Athlete country', 'Athlete year of birth', 'Athlete gender',
#        'Athlete age category', 'Athlete average speed', 'Athlete ID'],
#       dtype='object')

# %%
# Looking at the data type for each column
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
# Looking at the first 10 Rows in the dataframe(0-9)
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
""" Filtering Data"""
# Looking for USA races & athlete club(s) for athlete(s) that covered a distance of 50km or 50mi in 2020
# Creating a variable named filt to filter out the requested data
filt = (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA') & (df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2020)

# %%
#Using the pandas loc function to locate the rows of the filter(filt) as well as showing the columns 
#we want to be associated with the rows.
df.loc[filt,['Event name','Athlete club','Event distance/length','Year of event']]
# Out:
#                                             Event name  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)
# 2539946  West Seattle Beach Run - Winter Edition (USA)
# 2539947  West Seattle Beach Run - Winter Edition (USA)
# 2539948  West Seattle Beach Run - Winter Edition (USA)
# 2539949  West Seattle Beach Run - Winter Edition (USA)
# ...                                                ...
# 2760957   Yankee Springs Fall Trail Run Festival (USA)
# 2760958   Yankee Springs Fall Trail Run Festival (USA)
# 2760959   Yankee Springs Fall Trail Run Festival (USA)
# 2760960   Yankee Springs Fall Trail Run Festival (USA)
# 2760961   Yankee Springs Fall Trail Run Festival (USA)
#
#                    Athlete club Event distance/length  Year of event
# 2539945      *Normandy Park, WA                  50km           2020
# 2539946           *Gold Bar, WA                  50km           2020
# 2539947             *Vashon, WA                  50km           2020
# ...

# %% [markdown]
# Creating New Dataframe from Pre-existing Dataframe and Cleaning up the Data

# %%
# Creating a new dataframe that only stores races ran in the USA
usa_races = df[(df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA') & (df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2020)]

# %%
# Looking at the number of rows and columns in the usa_races dataframe (26,090 Rows) X (13 Columns)
usa_races.shape
# Out:
# (26090, 13)

# %%
# Looking at the first 5 rows of the usa_races dataframe
usa_races.head(5)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20           3:17:55 h
# 2539946                         20           4:02:32 h
# 2539947                         20           4:07:57 h
# 2539948                         20           4:22:02 h
# ...

# %%
# Removing (USA) from the event name column in the usa_races dataframe as it seems redundant
usa_races['Event name'] = usa_races['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\Henry Nkeki Bill\AppData\Local\Temp\ipykernel_23016\3567210003.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa_races['Event name'] = usa_races['Event name'].str.split('(').str.get(0)

# %%
usa_races.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
# ...

# %%
# Creating a new column for athlete age 
usa_races['Age'] = usa_races['Year of event'] - usa_races['Athlete year of birth']
# Out:
# C:\Users\Henry Nkeki Bill\AppData\Local\Temp\ipykernel_23016\2943701774.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa_races['Age'] = usa_races['Year of event'] - usa_races['Athlete year of birth']

# %%
# Removing the 'h' from athletes performance 
usa_races['Athlete performance'] = usa_races['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\Henry Nkeki Bill\AppData\Local\Temp\ipykernel_23016\2298356069.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa_races['Athlete performance'] = usa_races['Athlete performance'].str.split(' ').str.get(0)

# %%
usa_races.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# Age                          float64
# dtype: object

# %%
usa_races.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
usa_races.columns
# Out:
# Index(['Year of event', 'Event dates', 'Event name', 'Event distance/length',
#        'Event number of finishers', 'Athlete performance', 'Athlete club',
#        'Athlete country', 'Athlete year of birth', 'Athlete gender',
#        'Athlete age category', 'Athlete average speed', 'Athlete ID', 'Age'],
#       dtype='object')

# %%
# Data Cleaning
# drop columns: # Athlete club, Athlete Country, Athlete Age Category

usa_races = usa_races.drop(columns=['Athlete club','Athlete country','Athlete age category'])

# %%
usa_races
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...                ...         ...                                       ...
# 2760957           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760958           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760959           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760960           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760961           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
# ...

# %%
# Looking for columns that contains null values 
usa_races.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete year of birth        233
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# Age                          233
# dtype: int64

# %%
#Dropping/Deleting all rows that has null values
usa_races = usa_races.dropna()

# %%
usa_races
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...                ...         ...                                       ...
# 2760957           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760958           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760959           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760960           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760961           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
# ...

# %%
# Looking for duplicate Values(No duplicates found in our dataframe)
usa_races[usa_races.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete year of birth, Athlete gender, Athlete average speed, Athlete ID, Age]
# Index: []

# %%
# Reset Index
usa_races.reset_index(drop= True,inplace=True)

# %%
# Renaming column: Age ------------> Athlete age
usa_races.rename(columns={'Age':'Athlete age'},inplace=True)
# Out:
# C:\Users\Henry Nkeki Bill\AppData\Local\Temp\ipykernel_23016\3747886994.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa_races.rename(columns={'Age':'Athlete age'},inplace=True)

# %%
# Changing Data type
usa_races['Athlete age'] = usa_races['Athlete age'].astype(int)
# Out:
# C:\Users\Henry Nkeki Bill\AppData\Local\Temp\ipykernel_23016\1355394726.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa_races['Athlete age'] = usa_races['Athlete age'].astype(int)

# %%
#Dropping 'Athlete year of birth' column
usa_races = usa_races.drop(columns=['Athlete year of birth'])

# %%
# Changing Data type
usa_races['Athlete average speed'] =  usa_races['Athlete average speed'].astype(float)

# %%
usa_races
# Out:
#        Year of event Event dates                                Event name  \
# 0               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...              ...         ...                                       ...
# 25852           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25853           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25854           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25855           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25856           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
usa_races.columns
# Out:
# Index(['Year of event', 'Event dates', 'Event name', 'Event distance/length',
#        'Event number of finishers', 'Athlete performance', 'Athlete gender',
#        'Athlete average speed', 'Athlete ID', 'Athlete age'],
#       dtype='object')

# %%
# Renaming columns
usa_races.rename(columns={'Year of event':'year','Event dates':'date','Event distance/length':'distance_covered',
                          'Event number of finishers':'number_of_finishers','Athlete gender':'gender',
                          'Athlete average speed':'average_speed','Athlete ID':'athlete_id','Athlete age':'age',
                          'Athlete performance':'athlete_performance','Event name':'event_name'},inplace=True)

# %%
# Changed column names
usa_races.columns
# Out:
# Index(['year', 'date', 'event_name', 'distance_covered', 'number_of_finishers',
#        'athlete_performance', 'gender', 'average_speed', 'athlete_id', 'age'],
#       dtype='object')

# %%
# Reordering the data column
usa_races = usa_races[['date','athlete_id','gender','age','event_name','distance_covered','average_speed','athlete_performance','number_of_finishers','year']]

# %%
# Dropping 'year' column 
usa_races.drop(columns='year',inplace=True)
# Out:
# C:\Users\Henry Nkeki Bill\AppData\Local\Temp\ipykernel_23016\3911014184.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa_races.drop(columns='year',inplace=True)

# %%
# Renaming  'distance_covered' column to 'distance'
usa_races.rename(columns={'distance_covered':'distance'},inplace= True)
# Out:
# C:\Users\Henry Nkeki Bill\AppData\Local\Temp\ipykernel_23016\3781140240.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa_races.rename(columns={'distance_covered':'distance'},inplace= True)

# %%
usa_races.head()
# Out:
#          date  athlete_id gender  age  \
# 0  02.02.2020       71287      M   29
# 1  02.02.2020      629508      M   39
# 2  02.02.2020       64838      M   21
# 3  02.02.2020      704450      M   37
# 4  02.02.2020      810281      M   43
#
#                                  event_name distance  average_speed  \
# 0  West Seattle Beach Run - Winter Edition      50km         15.158
# 1  West Seattle Beach Run - Winter Edition      50km         12.369
# 2  West Seattle Beach Run - Winter Edition      50km         12.099
# 3  West Seattle Beach Run - Winter Edition      50km         11.449
# 4  West Seattle Beach Run - Winter Edition      50km         11.212
#
#   athlete_performance  number_of_finishers
# 0             3:17:55                   20
# 1             4:02:32                   20
# 2             4:07:57                   20
# 3             4:22:02                   20
# 4             4:27:34                   20

# %% [markdown]
# Charts & Graphs

# %%
# Histogram showing the number of people who ran 50Km and 50mi
sb.histplot(usa_races['distance'])
# Out:
# <Axes: xlabel='distance', ylabel='Count'>

# %%
# Looking at distance ran by both male & female
sb.histplot(usa_races, x='distance', hue='gender')
# Out:
# <Axes: xlabel='distance', ylabel='Count'>

# %%
# Seeing the distribution between 50mi and the average speed 
sb.displot(usa_races[usa_races['distance']== '50mi']['average_speed'])

# %%
sb.violinplot(data=usa_races,x='distance',y='average_speed',hue='gender',split=True,inner='quart',linewidth=1)
# Out:
# <Axes: xlabel='distance', ylabel='average_speed'>

# %%
usa_races.columns
# Out:
# Index(['date', 'athlete_id', 'gender', 'age', 'event_name', 'distance',
#        'average_speed', 'athlete_performance', 'number_of_finishers'],
#       dtype='object')

# %%
sb.lmplot(data=usa_races,x='age',y='average_speed',hue='gender')

# %% [markdown]
# Questions

# %%
usa_races.columns
# Out:
# Index(['date', 'athlete_id', 'gender', 'age', 'event_name', 'distance',
#        'average_speed', 'athlete_performance', 'number_of_finishers'],
#       dtype='object')

# %%
# what's the difference in speed for the 50km,50mi male to female
usa_races.groupby(['distance','gender'])['average_speed'].mean()
# Out:
# distance  gender
# 50km      F         7.083011
#           M         7.738985
# 50mi      F         6.834371
#           M         7.257633
# Name: average_speed, dtype: float64

# %%
# What age group are the best in the 50m Distance (20 + Distance min) (show 10)
usa_races.query('distance== "50mi"').groupby('age')['average_speed'].agg(['mean','count']).sort_values('mean',ascending=False).query('count>19').head(10)
# Out:
#          mean  count
# age
# 29   7.902252    135
# 23   7.779800     55
# 28   7.575252    107
# 30   7.569204    157
# 25   7.540923     91
# 31   7.451638    138
# 38   7.430022    231
# 35   7.422359    195
# 36   7.403854    185
# 26   7.379800     75

# %%
# What age group are the worst in the 50m Distance (20 + Distance min) (show 15) 
usa_races.query('distance== "50mi"').groupby('age')['average_speed'].agg(['mean','count']).sort_values('mean',ascending=True).query('count>19').head(15)
# Out:
#          mean  count
# age
# 60   6.261788     33
# 62   6.272730     37
# 61   6.358355     31
# 63   6.514806     31
# 58   6.582328     67
# 64   6.620727     22
# 50   6.671541    172
# 59   6.672072     83
# 48   6.696853    136
# 56   6.708373     67
# 53   6.736969     96
# 57   6.783205     78
# 49   6.789553    159
# 54   6.805506     83
# 55   6.828623     69

# %%
usa_races
# Out:
#              date  athlete_id gender  age  \
# 0      02.02.2020       71287      M   29
# 1      02.02.2020      629508      M   39
# 2      02.02.2020       64838      M   21
# 3      02.02.2020      704450      M   37
# 4      02.02.2020      810281      M   43
# ...           ...         ...    ...  ...
# 25852  03.10.2020      816361      F   62
# 25853  03.10.2020      326469      F   43
# 25854  03.10.2020      372174      F   58
# 25855  03.10.2020      860349      F   39
# 25856  03.10.2020      770097      M   40
#
#                                      event_name distance  average_speed  \
# 0      West Seattle Beach Run - Winter Edition      50km         15.158
# 1      West Seattle Beach Run - Winter Edition      50km         12.369
# 2      West Seattle Beach Run - Winter Edition      50km         12.099
# 3      West Seattle Beach Run - Winter Edition      50km         11.449
# 4      West Seattle Beach Run - Winter Edition      50km         11.212
# ...

# %%
# Which season is easier to run a race 
usa_races['race_month'] = usa_races['date'].str.split('.').str.get(1).astype(int)
usa_races['race_season'] = usa_races['race_month'].apply(lambda x: 'Winter' if x > 11 else 'Fall' if x > 8 else 'Summer' if x > 5 else 'Spring' if x > 2 else 'Winter' )
usa_races.groupby('race_season')['average_speed'].agg(['mean','count']).sort_values('mean',ascending=False)
# Out:
#                  mean  count
# race_season
# Spring       7.684430   3294
# Winter       7.518187  11595
# Fall         7.406619   8315
# Summer       6.869336   2653

# %%
# 50mi only
usa_races.query('distance == "50mi"').groupby('race_season')['average_speed'].agg(['mean','count']).sort_values('mean',ascending=False)
# Out:
#                  mean  count
# race_season
# Fall         7.511585   1997
# Spring       7.082557    836
# Winter       7.048442   1977
# Summer       6.505776    817
